# %% [markdown]
# ## Ejemplo 6: Sort
#
# ### 1. Objetivos:
#     - Aprender a usar `sort_values` para reordenar nuestros datos
#
# ---
#
# ### 2. Desarrollo:

# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/new_york_times_bestsellers-dirty.csv', index_col=0)
df.head(3)
# Out:
#                                   amazon_product_url             author  \
# 0  http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 1  http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 2  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
#
#                                          description      publisher  \
# 0  Descr: Aliens have taken control of the minds ...  Little, Brown
# 1  Descr: A woman's happy marriage is shaken when...   St. Martin's
# 2  Descr: A Massachusetts state investigator and ...         Putnam
#
#                       title                       oid  \
# 0                  THE HOST  5b4aa4ead3089013507db18c
# 1  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2                 THE FRONT  5b4aa4ead3089013507db18e
#
#   bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0         2008-05-24 00:00:00              1212883200000              2
# 1         2008-05-24 00:00:00              1212883200000              3
# 2         2008-05-24 00:00:00              1212883200000              4
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95

# %% [markdown]
# Por ejemplo, queremos ordenar nuestras entradas empezando por el libro de mayor precio hasta el libro de menor precio. Esto es un ordenamiento usando la columna 'price.numberDouble' de manera descendente. Esto se haría de la siguiente manera usando el método:
#
# `dataframe.sort_values(-columna-, ascending=False)`

# %%
df.sort_values("price.numberDouble", ascending=False).head(1)
# Out:
#                                      amazon_product_url           author  \
# 2264  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...  Haruki Murakami
#
#                                             description publisher title  \
# 2264  Descr: In 1980s Tokyo, a woman who punishes pe...     Knopf  1Q84
#
#                            oid bestsellers_date.numberLong  \
# 2264  5b4aa4ead3089013507dbff5         2011-12-03 00:00:00
#
#       published_date.numberLong rank.numberInt  rank_last_week.numberInt  \
# 2264              1324166400000             11                        12
#
#       weeks_on_list.numberInt  price.numberDouble
# 2264                        6                30.5

# %% [markdown]
# Si ordenamos en base a 'published_date.numberLong' podemos también obtener la lista desde la publicación más antigua hasta la publicación más reciente:

# %%
ordenado_fecha_publicacion = df.sort_values("published_date.numberLong")
ordenado_fecha_publicacion
# Out:
#                                      amazon_product_url             author  \
# 0     http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 1     http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 2     http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
# 3     http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...    Chuck Palahniuk
# 5     http://www.amazon.com/Phantom-Prey-John-Sandfo...      John Sandford
# ...                                                 ...                ...
# 3026  http://www.amazon.com/Dont-Go-Lisa-Scottoline-...    Lisa Scottoline
# 3027  http://www.amazon.com/Unintended-Consequences-...       Stuart Woods
# 3028  http://www.amazon.com/Six-Years-Harlan-Coben/d...       Harlan Coben
# 3029  http://www.amazon.com/The-Interestings-Novel-M...       Meg Wolitzer
# 3031  http://www.amazon.com/The-Storyteller-Jodi-Pic...       Jodi Picoult
#
#                                             description            publisher  \
# 0     Descr: Aliens have taken control of the minds ...        Little, Brown
# 1     Descr: A woman's happy marriage is shaken when...         St. Martin's
# 2     Descr: A Massachusetts state investigator and ...               Putnam
# 3     Descr: An aging porn queens aims to cap her ca...            Doubleday
# 5     Descr: The Minneapolis detective Lucas Davenpo...               Putnam
# ...                                                 ...                  ...
# 3026  Descr: An Army doctor returns from Afghanistan...         St. Martin's
# 3027  Descr: The New York lawyer Stone Barrington di...               Putnam
# 3028  Descr: Jake Fisher discovers that neither the ...               Dutton
# 3029  Descr: Six friends meet in the 1970s at a summ...            Riverhead
# 3031  Descr: A New Hampshire baker finds herself in ...  Emily Bestler/Atria
#
#                          title                       oid  \
# 0                     THE HOST  5b4aa4ead3089013507db18c
# 1     LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2                    THE FRONT  5b4aa4ead3089013507db18e
# 3                        SNUFF  5b4aa4ead3089013507db18f
# 5                 PHANTOM PREY  5b4aa4ead3089013507db191
# ...                        ...                       ...
# 3026                  DON'T GO  5b4aa4ead3089013507dc591
# 3027   UNINTENDED CONSEQUENCES  5b4aa4ead3089013507dc592
# 3028                 SIX YEARS  5b4aa4ead3089013507dc593
# 3029          THE INTERESTINGS  5b4aa4ead3089013507dc595
# 3031           THE STORYTELLER  5b4aa4ead3089013507dc598
#
#      bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0            2008-05-24 00:00:00              1212883200000              2
# 1            2008-05-24 00:00:00              1212883200000              3
# 2            2008-05-24 00:00:00              1212883200000              4
# 3            2008-05-24 00:00:00              1212883200000              5
# 5            2008-05-24 00:00:00              1212883200000              7
# ...                          ...                        ...            ...
# 3026         2013-04-20 00:00:00              1367712000000              7
# 3027         2013-04-20 00:00:00              1367712000000              8
# 3028         2013-04-20 00:00:00              1367712000000              9
# 3029         2013-04-20 00:00:00              1367712000000             11
# 3031         2013-04-20 00:00:00              1367712000000             14
#
#       rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                            1                        3               25.99
# 1                            2                        2               24.95
# 2                            0                        1               22.95
# 3                            0                        1               24.95
# 5                            4                        3               26.95
# ...                        ...                      ...                 ...
# 3026                         2                        2               27.99
# 3027                         4                        2               26.95
# 3028                         8                        5               27.95
# 3029                        11                        2               27.95
# 3031                        10                        8               28.99
#
# [2266 rows x 12 columns]

# %% [markdown]
# Per como seguramente no lo crees aún, vamos a convertir la fechas timestamp a datetime con el método:
#
# `pd.to_datetime(-dataframe[columna]-, unit="ms")`

# %%
ordenado_fecha_publicacion["published_date.numberLong"] = \
    pd.to_datetime(
    ordenado_fecha_publicacion["published_date.numberLong"],
    unit="ms")
ordenado_fecha_publicacion[["amazon_product_url",
    "published_date.numberLong"]]
# Out:
#                                      amazon_product_url  \
# 0     http://www.amazon.com/The-Host-Novel-Stephenie...
# 1     http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2     http://www.amazon.com/The-Front-Garano-Patrici...
# 3     http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 5     http://www.amazon.com/Phantom-Prey-John-Sandfo...
# ...                                                 ...
# 3026  http://www.amazon.com/Dont-Go-Lisa-Scottoline-...
# 3027  http://www.amazon.com/Unintended-Consequences-...
# 3028  http://www.amazon.com/Six-Years-Harlan-Coben/d...
# 3029  http://www.amazon.com/The-Interestings-Novel-M...
# 3031  http://www.amazon.com/The-Storyteller-Jodi-Pic...
#
#      published_date.numberLong
# 0                   2008-06-08
# 1                   2008-06-08
# 2                   2008-06-08
# 3                   2008-06-08
# 5                   2008-06-08
# ...                        ...
# 3026                2013-05-05
# 3027                2013-05-05
# 3028                2013-05-05
# 3029                2013-05-05
# 3031                2013-05-05
#
# [2266 rows x 2 columns]

# %% [markdown]
# **NOTA PYTHONESCA:** Si convertimos 'published_date.numberLong' a `datetime` desde el dataframe inicial `df`, podemos también ordenar usando el tipo `datetime`, ordenar fechas usando tipo de datos `datetime` o `int` (en alguna unidad de segundos) está bien, el ordenamiento se realizará de forma correcta, pero ordenar fechas de tipo `object` o `str` podríamos obtener resultados inesperados.

# %%
df['published_date.numberLong'] = pd.to_datetime(
    df['published_date.numberLong'], unit='ms')
df.sort_values('published_date.numberLong')[ ["amazon_product_url",
    "published_date.numberLong"] ]
# Out:
#                                      amazon_product_url  \
# 0     http://www.amazon.com/The-Host-Novel-Stephenie...
# 1     http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2     http://www.amazon.com/The-Front-Garano-Patrici...
# 3     http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 5     http://www.amazon.com/Phantom-Prey-John-Sandfo...
# ...                                                 ...
# 3026  http://www.amazon.com/Dont-Go-Lisa-Scottoline-...
# 3027  http://www.amazon.com/Unintended-Consequences-...
# 3028  http://www.amazon.com/Six-Years-Harlan-Coben/d...
# 3029  http://www.amazon.com/The-Interestings-Novel-M...
# 3031  http://www.amazon.com/The-Storyteller-Jodi-Pic...
#
#      published_date.numberLong
# 0                   2008-06-08
# 1                   2008-06-08
# 2                   2008-06-08
# 3                   2008-06-08
# 5                   2008-06-08
# ...                        ...
# 3026                2013-05-05
# 3027                2013-05-05
# 3028                2013-05-05
# 3029                2013-05-05
# 3031                2013-05-05
#
# [2266 rows x 2 columns]

# %% [markdown]
# Por ejemplo, podríamos primero filtrar para sólo tener los libros de la editorial que tiene más libros como 'best sellers' usando la columna `publisher` y después ordenarlos del que pasó más días en la lista de 'best sellers' al que pasó menos días en la lista usando la columna `weeks_on_list.numberInt`.
#
# Primero encontramos la editorial con más bestsellers con el método:
#
# `dataframe[-columna-].value_counts()`

# %%
df["publisher"].value_counts()
# Out:
# Putnam                                     267
# Grand Central                              227
# Knopf                                      216
# Little, Brown                              211
# Doubleday                                  153
#                                           ...
# Tor/ Tom Doherty                             1
# Ecco/HarperCollins                           1
# Viking,                                      1
# Harper Voyager/HarperCollins Publishers      1
# Berkeley Prime Crime                         1
# Name: publisher, Length: 69, dtype: int64

# %% [markdown]
# Filtra sólo los que perteneces a la editorial encontrada (Putnam?) usando la aplicación de filtros con:
#
# `dataframe[ dataframe[-columna-] op -valor- ]`

# %%
df_1 =  df[ df["publisher"] == "Putnam" ]
df_1.head(3)
# Out:
#                                    amazon_product_url             author  \
# 2   http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
# 5   http://www.amazon.com/Phantom-Prey-John-Sandfo...      John Sandford
# 17  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
#
#                                           description publisher         title  \
# 2   Descr: A Massachusetts state investigator and ...    Putnam     THE FRONT
# 5   Descr: The Minneapolis detective Lucas Davenpo...    Putnam  PHANTOM PREY
# 17  Descr: A Massachusetts state investigator and ...    Putnam     THE FRONT
#
#                          oid bestsellers_date.numberLong  \
# 2   5b4aa4ead3089013507db18e         2008-05-24 00:00:00
# 5   5b4aa4ead3089013507db191         2008-05-24 00:00:00
# 17  5b4aa4ead3089013507db1a5         2008-05-31 00:00:00
#
#    published_date.numberLong rank.numberInt  rank_last_week.numberInt  \
# 2                 2008-06-08              4                         0
# 5                 2008-06-08              7                         4
# 17                2008-06-15              7                         4
#
#     weeks_on_list.numberInt  price.numberDouble
# 2                         1               22.95
# 5                         3               26.95
# 17                        2               22.95

# %% [markdown]
# Ordenando en base a la cantidad de días como bestsellers usando:
#
# `dataframe.sort_values(-columna-, ascending=False)`

# %%
df_1.sort_values("weeks_on_list.numberInt", ascending=False)
# Out:
#                                      amazon_product_url             author  \
# 470   http://www.amazon.com/Scarpetta-Kay-Patricia-C...  Patricia Cornwell
# 455   http://www.amazon.com/Scarpetta-Kay-Patricia-C...  Patricia Cornwell
# 438   http://www.amazon.com/Scarpetta-Kay-Patricia-C...  Patricia Cornwell
# 421   http://www.amazon.com/Scarpetta-Kay-Patricia-C...  Patricia Cornwell
# 1072  http://www.amazon.com/U-Undertow-Kinsey-Millho...        Sue Grafton
# ...                                                 ...                ...
# 925   http://www.amazon.com/The-Scarpetta-Factor-Nov...  Patricia Cornwell
# 2150  http://www.amazon.com/Son-Stone-Barrington-Nov...       Stuart Woods
# 2137  http://www.amazon.com/Killing-Blues-Jesse-Ston...   Michael Brandman
# 993   http://www.amazon.com/U-Undertow-Kinsey-Millho...        Sue Grafton
# 2     http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
#
#                                             description publisher  \
# 470   Descr: The forensic pathologist Kay Scarpetta ...    Putnam
# 455   Descr: The forensic pathologist Kay Scarpetta ...    Putnam
# 438   Descr: The forensic pathologist Kay Scarpetta ...    Putnam
# 421   Descr: The forensic pathologist Kay Scarpetta ...    Putnam
# 1072  Descr: Kinsey Millhone investigates the case o...    Putnam
# ...                                                 ...       ...
# 925   Descr: Apparent threats on Kay Scarpetta’s  li...    Putnam
# 2150  Descr: The New York lawyer Stone Barrington ge...    Putnam
# 2137  Descr: Jesse Stone, the chief of police in Par...    Putnam
# 993   Descr: Kinsey Millhone investigates the case o...    Putnam
# 2     Descr: A Massachusetts state investigator and ...    Putnam
#
#                                      title                       oid  \
# 470                              SCARPETTA  5b4aa4ead3089013507db491
# 455                              SCARPETTA  5b4aa4ead3089013507db47c
# 438                              SCARPETTA  5b4aa4ead3089013507db466
# 421                              SCARPETTA  5b4aa4ead3089013507db44c
# 1072                     U IS FOR UNDERTOW  5b4aa4ead3089013507db84e
# ...                                    ...                       ...
# 925                   THE SCARPETTA FACTOR  5b4aa4ead3089013507db754
# 2150                          SON OF STONE  5b4aa4ead3089013507dbf27
# 2137  ROBERT B. PARKER’S KILLING THE BLUES  5b4aa4ead3089013507dbf13
# 993                      U IS FOR UNDERTOW  5b4aa4ead3089013507db7cb
# 2                                THE FRONT  5b4aa4ead3089013507db18e
#
#      bestsellers_date.numberLong published_date.numberLong rank.numberInt  \
# 470          2009-02-14 00:00:00                2009-03-01             15
# 455          2009-02-07 00:00:00                2009-02-22             14
# 438          2009-01-31 00:00:00                2009-02-15             12
# 421          2009-01-24 00:00:00                2009-02-08              6
# 1072         2010-01-17 00:00:00                2010-01-31             12
# ...                          ...                       ...            ...
# 925          2009-10-24 00:00:00                2009-11-08              2
# 2150         2011-09-24 00:00:00                2011-10-09              5
# 2137         2011-09-17 00:00:00                2011-10-02              5
# 993          2009-12-05 00:00:00                2009-12-20              1
# 2            2008-05-24 00:00:00                2008-06-08              4
#
#       rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 470                         14                       11               27.95
# 455                         12                       10               27.95
# 438                          6                        9               27.95
# 421                          6                        8               27.95
# 1072                        11                        7               27.95
# ...                        ...                      ...                 ...
# 925                          0                        1               27.95
# 2150                         0                        1               26.95
# 2137                         0                        1               25.95
# 993                          0                        1               27.95
# 2                            0                        1               22.95
#
# [267 rows x 12 columns]

# %%
df_1.sort_values(["weeks_on_list.numberInt", "price.numberDouble"], ascending=False)
# Out:
#                                     amazon_product_url             author  \
# 470  http://www.amazon.com/Scarpetta-Kay-Patricia-C...  Patricia Cornwell
# 455  http://www.amazon.com/Scarpetta-Kay-Patricia-C...  Patricia Cornwell
# 438  http://www.amazon.com/Scarpetta-Kay-Patricia-C...  Patricia Cornwell
# 421  http://www.amazon.com/Scarpetta-Kay-Patricia-C...  Patricia Cornwell
# 409  http://www.amazon.com/Scarpetta-Kay-Patricia-C...  Patricia Cornwell
# ..                                                 ...                ...
# 110  http://www.amazon.com/Killer-View-Fleming-Ridl...     Ridley Pearson
# 522  http://www.amazon.com/The-Help-Kathryn-Stocket...   Kathryn Stockett
# 541  http://www.amazon.com/Pursuit-Karen-Robards/dp...      Karen Robards
# 584  http://www.amazon.com/Perfect-Poison-Arcane-So...       Amanda Quick
# 2    http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
#
#                                            description publisher  \
# 470  Descr: The forensic pathologist Kay Scarpetta ...    Putnam
# 455  Descr: The forensic pathologist Kay Scarpetta ...    Putnam
# 438  Descr: The forensic pathologist Kay Scarpetta ...    Putnam
# 421  Descr: The forensic pathologist Kay Scarpetta ...    Putnam
# 409  Descr: The forensic pathologist Kay Scarpetta ...    Putnam
# ..                                                 ...       ...
# 110  Descr: A sheriff in Sun Valley, Idaho, investi...    Putnam
# 522  Descr: A young white woman and two black maids...    Putnam
# 541  Descr: A lawyer survives a suspicious car cras...    Putnam
# 584  Descr: A Victorian botanist investigates a poi...    Putnam
# 2    Descr: A Massachusetts state investigator and ...    Putnam
#
#                   title                       oid bestsellers_date.numberLong  \
# 470           SCARPETTA  5b4aa4ead3089013507db491         2009-02-14 00:00:00
# 455           SCARPETTA  5b4aa4ead3089013507db47c         2009-02-07 00:00:00
# 438           SCARPETTA  5b4aa4ead3089013507db466         2009-01-31 00:00:00
# 421           SCARPETTA  5b4aa4ead3089013507db44c         2009-01-24 00:00:00
# 409           SCARPETTA  5b4aa4ead3089013507db438         2009-01-17 00:00:00
# ..                  ...                       ...                         ...
# 110         KILLER VIEW  5b4aa4ead3089013507db239         2008-07-19 00:00:00
# 522            THE HELP  5b4aa4ead3089013507db4e2         2009-03-14 00:00:00
# 541             PURSUIT  5b4aa4ead3089013507db502         2009-03-28 00:00:00
# 584  THE PERFECT POISON  5b4aa4ead3089013507db54f         2009-04-25 00:00:00
# 2             THE FRONT  5b4aa4ead3089013507db18e         2008-05-24 00:00:00
#
#     published_date.numberLong rank.numberInt  rank_last_week.numberInt  \
# 470                2009-03-01             15                        14
# 455                2009-02-22             14                        12
# 438                2009-02-15             12                         6
# 421                2009-02-08              6                         6
# 409                2009-02-01              6                         4
# ..                        ...            ...                       ...
# 110                2008-08-03             15                         0
# 522                2009-03-29             16                         0
# 541                2009-04-12              8                         0
# 584                2009-05-10              5                         0
# 2                  2008-06-08              4                         0
#
#      weeks_on_list.numberInt  price.numberDouble
# 470                       11               27.95
# 455                       10               27.95
# 438                        9               27.95
# 421                        8               27.95
# 409                        7               27.95
# ..                       ...                 ...
# 110                        1               24.95
# 522                        1               24.95
# 541                        1               24.95
# 584                        1               24.95
# 2                          1               22.95
#
# [267 rows x 12 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reto 6: Sort
#
# ### 1. Objetivos:
#     - Practicar el uso de `sort_values` para obtener datos específicos
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# #### a) Reordenamiento para hallazgo de valores
#
# Vamos a trabajar sobre el dataset que guardaste en la sesión anterior. Tu Reto consiste en lo siguiente:
#
# 1. Usa `sort_values` y `loc` para obtener el valor de la velocidad en kilómetros por segundo más lenta de todos los objetos que tenemos en el dataset y asígnalo a `velocidad_en_kilometros_por_segundo_de_objeto_mas_lento`.
# 2. Usa `sort_values` y `loc` para obtener el valor del diámetro más grande medido que existe en nuestro dataset y asígnalo a `medida_de_diametro_mas_grande`

# %%
import pandas as pd

# %%
df_reto_6 = pd.read_csv("../Ejemplo-05/objetos_cercanos_5.csv", index_col=0)
df_reto_6.head(3)

# %%
# tu código
