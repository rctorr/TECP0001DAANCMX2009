# %% [markdown]
# ## Ejemplo 6: Automatizando peticiones
#
# ### 1. Objetivos:
#     - Usar todo lo que aprendimos para automatizar peticiones al API
#     - Guardar nuestros resultados en un archivo tipo .csv
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# Veamos cómo usar todo lo que aprendimos para automatizar el proceso de realizar múltiples peticiones a la API, reunirlas en un `DataFrame` y guardarlo en un .csv:

# %%
import pandas as pd
import requests
import time

# %%
url = 'https://api.nasa.gov/neo/rest/v1/neo/browse/'
parametros = {
    'api_key': 'EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'}

# %% [markdown]
# Obtener 10 páginas de datos del API.

# %%
dict_datos = {}
for i in range(10):  # [0,1,2,..,9]
    r = requests.get(url, params=parametros, timeout=5)
    if r.status_code == 200:
        datos = r.json()
        objetos = datos["near_earth_objects"]
        dict_datos[i] = objetos
        # siguiente url
        url = datos["links"]["next"]
    else: # en caso de error
        print("Error al leer", url)

# %%
dict_datos[9]
# Out:
# [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3986728?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3986728',
#   'neo_reference_id': '3986728',
#   'name': '(2020 BL)',
#   'designation': '2020 BL',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986728',
#   'absolute_magnitude_h': 26.931,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0109233281,
#     'estimated_diameter_max': 0.0244253041},
#    'meters': {'estimated_diameter_min': 10.92332805,
#     'estimated_diameter_max': 24.4253040604},
#    'miles': {'estimated_diameter_min': 0.0067874393,
#     'estimated_diameter_max': 0.0151771756},
#    'feet': {'estimated_diameter_min': 35.8376915996,
#     'estimated_diameter_max': 80.1355145735}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '1962-03-20',
#     'close_approach_date_full': '1962-Mar-20 08:29',
#     'epoch_date_close_approach': -245691060000,
#     'relative_velocity': {'kilometers_per_second': '21.6535902345',
#      'kilometers_per_hour': '77952.9248440978',
#      'miles_per_hour': '48436.9159954895'},
#     'miss_distance': {'astronomical': '0.4992597032',
#      'lunar': '194.2120245448',
#      'kilometers': '74688188.175552184',
#      'miles': '46409088.1142767792'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2020-01-17',
#     'close_approach_date_full': '2020-Jan-17 11:45',
#     'epoch_date_close_approach': 1579261500000,
#     'relative_velocity': {'kilometers_per_second': '6.9912780728',
#      'kilometers_per_hour': '25168.6010622108',
#      'miles_per_hour': '15638.7899211276'},
#     'miss_distance': {'astronomical': '0.0209651907',
#      'lunar': '8.1554591823',
#      'kilometers': '3136347.872863809',
#      'miles': '1948836.1994622042'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '2',
#    'orbit_determination_date': '2020-02-03 05:38:46',
#    'first_observation_date': '2020-01-18',
#    'last_observation_date': '2020-02-02',
#    'data_arc_in_days': 15,
#    'observations_used': 23,
#    'orbit_uncertainty': '7',
#    'minimum_orbit_intersection': '.0208627',
#    'jupiter_tisserand_invariant': '3.631',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.5071039116033665',
#    'semi_major_axis': '2.03393439410999',
#    'inclination': '5.282723143255806',
#    'ascending_node_longitude': '111.3521764008527',
#    'orbital_period': '1059.507017162461',
#    'perihelion_distance': '1.002518306912191',
#    'perihelion_argument': '8.227363955287679',
#    'aphelion_distance': '3.065350481307789',
#    'perihelion_time': '2458868.587550769741',
#    'mean_anomaly': '44.82129986271848',
#    'mean_motion': '.3397806660725483',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3986733?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3986733',
#   'neo_reference_id': '3986733',
#   'name': '(2020 BQ)',
#   'designation': '2020 BQ',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986733',
#   'absolute_magnitude_h': 24.668,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0309709821,
#     'estimated_diameter_max': 0.0692532212},
#    'meters': {'estimated_diameter_min': 30.970982058,
#     'estimated_diameter_max': 69.2532212116},
#    'miles': {'estimated_diameter_min': 0.0192444701,
#     'estimated_diameter_max': 0.0430319433},
#    'feet': {'estimated_diameter_min': 101.6108367752,
#     'estimated_diameter_max': 227.2087382799}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-01-18',
#     'close_approach_date_full': '2020-Jan-18 16:48',
#     'epoch_date_close_approach': 1579366080000,
#     'relative_velocity': {'kilometers_per_second': '17.5510972181',
#      'kilometers_per_hour': '63183.949985282',
#      'miles_per_hour': '39260.0493672437'},
#     'miss_distance': {'astronomical': '0.0324559866',
#      'lunar': '12.6253787874',
#      'kilometers': '4855346.464108542',
#      'miles': '3016972.3939281996'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '2',
#    'orbit_determination_date': '2020-03-01 05:06:42',
#    'first_observation_date': '2020-01-18',
#    'last_observation_date': '2020-01-26',
#    'data_arc_in_days': 8,
#    'observations_used': 54,
#    'orbit_uncertainty': '8',
#    'minimum_orbit_intersection': '.0295467',
#    'jupiter_tisserand_invariant': '4.394',
#    'epoch_osculation': '2458870.5',
#    'eccentricity': '.3219635178767732',
#    'semi_major_axis': '1.475662324380876',
#    'inclination': '30.62079881270648',
#    'ascending_node_longitude': '117.9282073762539',
#    'orbital_period': '654.7551315448446',
#    'perihelion_distance': '1.000552891224993',
#    'perihelion_argument': '18.81688784499064',
#    'aphelion_distance': '1.950771757536759',
#    'perihelion_time': '2458883.330789923232',
#    'mean_anomaly': '352.945325435686',
#    'mean_motion': '.5498238694985217',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3986736?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3986736',
#   'neo_reference_id': '3986736',
#   'name': '(2020 BT)',
#   'designation': '2020 BT',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986736',
#   'absolute_magnitude_h': 24.408,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0349104122,
#     'estimated_diameter_max': 0.0780620548},
#    'meters': {'estimated_diameter_min': 34.910412191,
#     'estimated_diameter_max': 78.0620547817},
#    'miles': {'estimated_diameter_min': 0.0216923177,
#     'estimated_diameter_max': 0.048505497},
#    'feet': {'estimated_diameter_min': 114.5354767329,
#     'estimated_diameter_max': 256.10911181}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-01-19',
#     'close_approach_date_full': '2020-Jan-19 17:10',
#     'epoch_date_close_approach': 1579453800000,
#     'relative_velocity': {'kilometers_per_second': '8.7792542837',
#      'kilometers_per_hour': '31605.3154213637',
#      'miles_per_hour': '19638.3139072357'},
#     'miss_distance': {'astronomical': '0.0877593044',
#      'lunar': '34.1383694116',
#      'kilometers': '13128605.010921628',
#      'miles': '8157736.8745013464'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '4',
#    'orbit_determination_date': '2020-02-20 04:52:35',
#    'first_observation_date': '2020-01-18',
#    'last_observation_date': '2020-02-19',
#    'data_arc_in_days': 32,
#    'observations_used': 24,
#    'orbit_uncertainty': '8',
#    'minimum_orbit_intersection': '.0615856',
#    'jupiter_tisserand_invariant': '3.336',
#    'epoch_osculation': '2458870.5',
#    'eccentricity': '.562265832570041',
#    'semi_major_axis': '2.330705970641104',
#    'inclination': '4.478362852922588',
#    'ascending_node_longitude': '139.6313795265512',
#    'orbital_period': '1299.659722294167',
#    'perihelion_distance': '1.020229637582618',
#    'perihelion_argument': '315.3927520659097',
#    'aphelion_distance': '3.64118230369959',
#    'perihelion_time': '2458850.702997023009',
#    'mean_anomaly': '5.483682343510867',
#    'mean_motion': '.2769955810929694',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3986774?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3986774',
#   'neo_reference_id': '3986774',
#   'name': '(2020 BX1)',
#   'designation': '2020 BX1',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986774',
#   'absolute_magnitude_h': 25.126,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0250815849,
#     'estimated_diameter_max': 0.0560841289},
#    'meters': {'estimated_diameter_min': 25.081584935,
#     'estimated_diameter_max': 56.084128898},
#    'miles': {'estimated_diameter_min': 0.0155849695,
#     'estimated_diameter_max': 0.0348490513},
#    'feet': {'estimated_diameter_min': 82.288667118,
#     'estimated_diameter_max': 184.0030534537}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '1973-05-04',
#     'close_approach_date_full': '1973-May-04 12:35',
#     'epoch_date_close_approach': 105366900000,
#     'relative_velocity': {'kilometers_per_second': '16.4821839152',
#      'kilometers_per_hour': '59335.8620947452',
#      'miles_per_hour': '36868.9971999265'},
#     'miss_distance': {'astronomical': '0.0748952662',
#      'lunar': '29.1342585518',
#      'kilometers': '11204172.296602994',
#      'miles': '6961949.8352055572'},
#     'orbiting_body': 'Mars'},
#    {'close_approach_date': '2020-01-20',
#     'close_approach_date_full': '2020-Jan-20 06:44',
#     'epoch_date_close_approach': 1579502640000,
#     'relative_velocity': {'kilometers_per_second': '13.1487515972',
#      'kilometers_per_hour': '47335.5057497494',
#      'miles_per_hour': '29412.4424476707'},
#     'miss_distance': {'astronomical': '0.0476179457',
#      'lunar': '18.5233808773',
#      'kilometers': '7123543.250495659',
#      'miles': '4426364.5226077342'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '1',
#    'orbit_determination_date': '2020-01-21 04:12:06',
#    'first_observation_date': '2019-12-30',
#    'last_observation_date': '2020-01-21',
#    'data_arc_in_days': 22,
#    'observations_used': 23,
#    'orbit_uncertainty': '8',
#    'minimum_orbit_intersection': '.0215537',
#    'jupiter_tisserand_invariant': '4.020',
#    'epoch_osculation': '2458861.5',
#    'eccentricity': '.5125298187326909',
#    'semi_major_axis': '1.713573125737326',
#    'inclination': '3.261162334984475',
#    'ascending_node_longitude': '82.52557191700917',
#    'orbital_period': '819.3178006212695',
#    'perihelion_distance': '.8353158022179638',
#    'perihelion_argument': '96.89180428358247',
#    'aphelion_distance': '2.591830449256688',
#    'perihelion_time': '2458910.238048311456',
#    'mean_anomaly': '338.5849918324493',
#    'mean_motion': '.4393899409081805',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3989254?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3989254',
#   'neo_reference_id': '3989254',
#   'name': '(2020 BE11)',
#   'designation': '2020 BE11',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989254',
#   'absolute_magnitude_h': 22.43,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0868070458,
#     'estimated_diameter_max': 0.1941064553},
#    'meters': {'estimated_diameter_min': 86.8070457914,
#     'estimated_diameter_max': 194.1064553155},
#    'miles': {'estimated_diameter_min': 0.0539393809,
#     'estimated_diameter_max': 0.1206121222},
#    'feet': {'estimated_diameter_min': 284.8000281143,
#     'estimated_diameter_max': 636.8322228574}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-01-05',
#     'close_approach_date_full': '2020-Jan-05 09:20',
#     'epoch_date_close_approach': 1578216000000,
#     'relative_velocity': {'kilometers_per_second': '13.9543160928',
#      'kilometers_per_hour': '50235.537933986',
#      'miles_per_hour': '31214.4096679259'},
#     'miss_distance': {'astronomical': '0.0767190287',
#      'lunar': '29.8437021643',
#      'kilometers': '11477003.281988869',
#      'miles': '7131479.1483456322'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '5',
#    'orbit_determination_date': '2020-02-26 07:28:41',
#    'first_observation_date': '2020-01-26',
#    'last_observation_date': '2020-02-21',
#    'data_arc_in_days': 26,
#    'observations_used': 35,
#    'orbit_uncertainty': '7',
#    'minimum_orbit_intersection': '.0026122',
#    'jupiter_tisserand_invariant': '3.890',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.484867563672234',
#    'semi_major_axis': '1.795073189446938',
#    'inclination': '15.2128814356987',
#    'ascending_node_longitude': '96.35862539510254',
#    'orbital_period': '878.4593458711727',
#    'perihelion_distance': '.9247004254664548',
#    'perihelion_argument': '325.8282467115266',
#    'aphelion_distance': '2.665445953427422',
#    'perihelion_time': '2458824.477062446950',
#    'mean_anomaly': '72.13567459545385',
#    'mean_motion': '.4098083783751952',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3989292?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3989292',
#   'neo_reference_id': '3989292',
#   'name': '(2020 BE13)',
#   'designation': '2020 BE13',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989292',
#   'absolute_magnitude_h': 26.25,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0149470324,
#     'estimated_diameter_max': 0.0334225806},
#    'meters': {'estimated_diameter_min': 14.9470324236,
#     'estimated_diameter_max': 33.422580561},
#    'miles': {'estimated_diameter_min': 0.0092876525,
#     'estimated_diameter_max': 0.0207678223},
#    'feet': {'estimated_diameter_min': 49.0388218565,
#     'estimated_diameter_max': 109.6541392077}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-01-21',
#     'close_approach_date_full': '2020-Jan-21 20:08',
#     'epoch_date_close_approach': 1579637280000,
#     'relative_velocity': {'kilometers_per_second': '11.7645379165',
#      'kilometers_per_hour': '42352.3364994198',
#      'miles_per_hour': '26316.0948654312'},
#     'miss_distance': {'astronomical': '0.0339817078',
#      'lunar': '13.2188843342',
#      'kilometers': '5083591.105842386',
#      'miles': '3158797.0378054868'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '1',
#    'orbit_determination_date': '2020-01-30 13:12:43',
#    'first_observation_date': '2020-01-28',
#    'last_observation_date': '2020-01-30',
#    'data_arc_in_days': 2,
#    'observations_used': 27,
#    'orbit_uncertainty': '8',
#    'minimum_orbit_intersection': '.0334676',
#    'jupiter_tisserand_invariant': '3.476',
#    'epoch_osculation': '2458877.5',
#    'eccentricity': '.5819692816557961',
#    'semi_major_axis': '2.134209546605095',
#    'inclination': '5.075230807001481',
#    'ascending_node_longitude': '141.7651165724571',
#    'orbital_period': '1138.817190490105',
#    'perihelion_distance': '.8921651498643854',
#    'perihelion_argument': '294.7222698660501',
#    'aphelion_distance': '3.376253943345804',
#    'perihelion_time': '2458838.032054758972',
#    'mean_anomaly': '12.47650668203847',
#    'mean_motion': '.3161174620529474',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3989293?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3989293',
#   'neo_reference_id': '3989293',
#   'name': '(2020 BG13)',
#   'designation': '2020 BG13',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989293',
#   'absolute_magnitude_h': 27.764,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0074431192,
#     'estimated_diameter_max': 0.0166433206},
#    'meters': {'estimated_diameter_min': 7.4431192415,
#     'estimated_diameter_max': 16.6433205887},
#    'miles': {'estimated_diameter_min': 0.0046249384,
#     'estimated_diameter_max': 0.0103416768},
#    'feet': {'estimated_diameter_min': 24.4196833324,
#     'estimated_diameter_max': 54.6040719203}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-01-28',
#     'close_approach_date_full': '2020-Jan-28 05:34',
#     'epoch_date_close_approach': 1580189640000,
#     'relative_velocity': {'kilometers_per_second': '8.6567249415',
#      'kilometers_per_hour': '31164.20978953',
#      'miles_per_hour': '19364.2280217221'},
#     'miss_distance': {'astronomical': '0.0068916721',
#      'lunar': '2.6808604469',
#      'kilometers': '1030979.466898427',
#      'miles': '640620.9347432126'},
#     'orbiting_body': 'Moon'},
#    {'close_approach_date': '2020-01-28',
#     'close_approach_date_full': '2020-Jan-28 11:55',
#     'epoch_date_close_approach': 1580212500000,
#     'relative_velocity': {'kilometers_per_second': '8.4889777725',
#      'kilometers_per_hour': '30560.3199811092',
#      'miles_per_hour': '18988.9943793731'},
#     'miss_distance': {'astronomical': '0.0055219241',
#      'lunar': '2.1480284749',
#      'kilometers': '826068.083661667',
#      'miles': '513294.9053863246'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '2',
#    'orbit_determination_date': '2020-02-03 05:40:21',
#    'first_observation_date': '2020-01-29',
#    'last_observation_date': '2020-01-30',
#    'data_arc_in_days': 1,
#    'observations_used': 42,
#    'orbit_uncertainty': '7',
#    'minimum_orbit_intersection': '.00502633',
#    'jupiter_tisserand_invariant': '4.395',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.3669136605420315',
#    'semi_major_axis': '1.527962382697591',
#    'inclination': '11.01754473942204',
#    'ascending_node_longitude': '128.0392995463637',
#    'orbital_period': '689.8702557202574',
#    'perihelion_distance': '.967332111691493',
#    'perihelion_argument': '335.8728473346216',
#    'aphelion_distance': '2.088592653703688',
#    'perihelion_time': '2458857.126829566205',
#    'mean_anomaly': '74.81746158526329',
#    'mean_motion': '.5218372542009987',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3989331?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3989331',
#   'neo_reference_id': '3989331',
#   'name': '(2020 BH14)',
#   'designation': '2020 BH14',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989331',
#   'absolute_magnitude_h': 18.929,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4352662328,
#     'estimated_diameter_max': 0.9732848848},
#    'meters': {'estimated_diameter_min': 435.2662327557,
#     'estimated_diameter_max': 973.2848847519},
#    'miles': {'estimated_diameter_min': 0.2704618143,
#     'estimated_diameter_max': 0.6047710021},
#    'feet': {'estimated_diameter_min': 1428.0388670741,
#     'estimated_diameter_max': 3193.1919812894}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [],
#   'orbital_data': {'orbit_id': '2',
#    'orbit_determination_date': '2020-02-16 05:09:42',
#    'first_observation_date': '2020-01-21',
#    'last_observation_date': '2020-02-15',
#    'data_arc_in_days': 25,
#    'observations_used': 16,
#    'orbit_uncertainty': '7',
#    'minimum_orbit_intersection': '.160789',
#    'jupiter_tisserand_invariant': '3.121',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.6643568561960105',
#    'semi_major_axis': '2.316806075152592',
#    'inclination': '28.72962619870264',
#    'ascending_node_longitude': '340.6010072211201',
#    'orbital_period': '1288.05068187893',
#    'perihelion_distance': '.777620074648398',
#    'perihelion_argument': '32.74065680558773',
#    'aphelion_distance': '3.855992075656786',
#    'perihelion_time': '2458683.064344891524',
#    'mean_anomaly': '88.72076032936167',
#    'mean_motion': '.2794921077754906',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3991546?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3991546',
#   'neo_reference_id': '3991546',
#   'name': '(2020 CZ1)',
#   'designation': '2020 CZ1',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991546',
#   'absolute_magnitude_h': 25.475,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0213577243,
#     'estimated_diameter_max': 0.0477573234},
#    'meters': {'estimated_diameter_min': 21.3577243277,
#     'estimated_diameter_max': 47.7573234414},
#    'miles': {'estimated_diameter_min': 0.0132710705,
#     'estimated_diameter_max': 0.0296750158},
#    'feet': {'estimated_diameter_min': 70.0712762833,
#     'estimated_diameter_max': 156.6841370396}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-01-15',
#     'close_approach_date_full': '2020-Jan-15 13:12',
#     'epoch_date_close_approach': 1579093920000,
#     'relative_velocity': {'kilometers_per_second': '8.8236021925',
#      'kilometers_per_hour': '31764.9678929581',
#      'miles_per_hour': '19737.5157443772'},
#     'miss_distance': {'astronomical': '0.0247226692',
#      'lunar': '9.6171183188',
#      'kilometers': '3698458.653034604',
#      'miles': '2298115.6419573752'},
#     'orbiting_body': 'Earth'},
#    {'close_approach_date': '2111-11-15',
#     'close_approach_date_full': '2111-Nov-15 12:54',
#     'epoch_date_close_approach': 4477035240000,
#     'relative_velocity': {'kilometers_per_second': '12.5225722607',
#      'kilometers_per_hour': '45081.2601383771',
#      'miles_per_hour': '28011.741889871'},
#     'miss_distance': {'astronomical': '0.0511341436',
#      'lunar': '19.8911818604',
#      'kilometers': '7649558.966834132',
#      'miles': '4753215.5324577416'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '1',
#    'orbit_determination_date': '2020-02-08 10:42:05',
#    'first_observation_date': '2020-02-02',
#    'last_observation_date': '2020-02-06',
#    'data_arc_in_days': 4,
#    'observations_used': 16,
#    'orbit_uncertainty': '8',
#    'minimum_orbit_intersection': '.0191627',
#    'jupiter_tisserand_invariant': '3.160',
#    'epoch_osculation': '2458882.5',
#    'eccentricity': '.6144353391365497',
#    'semi_major_axis': '2.525183358926546',
#    'inclination': '1.192415422548271',
#    'ascending_node_longitude': '11.08537465842315',
#    'orbital_period': '1465.675420766753',
#    'perihelion_distance': '.9736214654025419',
#    'perihelion_argument': '83.4235788605328',
#    'aphelion_distance': '4.076745252450549',
#    'perihelion_time': '2458848.797551855900',
#    'mean_anomaly': '8.278013781201848',
#    'mean_motion': '.2456205479734863',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3991649?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3991649',
#   'neo_reference_id': '3991649',
#   'name': '(2020 CB3)',
#   'designation': '2020 CB3',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991649',
#   'absolute_magnitude_h': 24.519,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.033170726,
#     'estimated_diameter_max': 0.0741719981},
#    'meters': {'estimated_diameter_min': 33.1707259756,
#     'estimated_diameter_max': 74.1719981444},
#    'miles': {'estimated_diameter_min': 0.0206113272,
#     'estimated_diameter_max': 0.0460883287},
#    'feet': {'estimated_diameter_min': 108.8278446098,
#     'estimated_diameter_max': 243.3464583922}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '1960-06-28',
#     'close_approach_date_full': '1960-Jun-28 22:14',
#     'epoch_date_close_approach': -300073560000,
#     'relative_velocity': {'kilometers_per_second': '14.798729822',
#      'kilometers_per_hour': '53275.427359079',
#      'miles_per_hour': '33103.2787387566'},
#     'miss_distance': {'astronomical': '0.0575191081',
#      'lunar': '22.3749330509',
#      'kilometers': '8604736.056059747',
#      'miles': '5346735.0538366286'},
#     'orbiting_body': 'Venus'},
#    {'close_approach_date': '2020-02-13',
#     'close_approach_date_full': '2020-Feb-13 08:49',
#     'epoch_date_close_approach': 1581583740000,
#     'relative_velocity': {'kilometers_per_second': '19.5548443011',
#      'kilometers_per_hour': '70397.439483946',
#      'miles_per_hour': '43742.2312171219'},
#     'miss_distance': {'astronomical': '0.0249304094',
#      'lunar': '9.6979292566',
#      'kilometers': '3729536.144467978',
#      'miles': '2317426.2996869764'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '7',
#    'orbit_determination_date': '2020-03-18 06:18:10',
#    'first_observation_date': '2020-02-15',
#    'last_observation_date': '2020-03-04',
#    'data_arc_in_days': 18,
#    'observations_used': 30,
#    'orbit_uncertainty': '8',
#    'minimum_orbit_intersection': '.016743',
#    'jupiter_tisserand_invariant': '3.353',
#    'epoch_osculation': '2458900.5',
#    'eccentricity': '.6871303453500962',
#    'semi_major_axis': '2.143116365998184',
#    'inclination': '7.37027853958787',
#    'ascending_node_longitude': '329.9776817738326',
#    'orbital_period': '1145.953660204202',
#    'perihelion_distance': '.6705160773044087',
#    'perihelion_argument': '94.53171874706973',
#    'aphelion_distance': '3.61571665469196',
#    'perihelion_time': '2458848.223181469567',
#    'mean_anomaly': '16.42270130504433',
#    'mean_motion': '.3141488286148064',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3994620?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '3994620',
#   'neo_reference_id': '3994620',
#   'name': '(2020 DS2)',
#   'designation': '2020 DS2',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3994620',
#   'absolute_magnitude_h': 21.683,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.122448925,
#     'estimated_diameter_max': 0.27380412},
#    'meters': {'estimated_diameter_min': 122.4489249646,
#     'estimated_diameter_max': 273.8041199927},
#    'miles': {'estimated_diameter_min': 0.076086211,
#     'estimated_diameter_max': 0.1701339398},
#    'feet': {'estimated_diameter_min': 401.735330981,
#     'estimated_diameter_max': 898.3075090369}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2017-10-19',
#     'close_approach_date_full': '2017-Oct-19 03:06',
#     'epoch_date_close_approach': 1508382360000,
#     'relative_velocity': {'kilometers_per_second': '8.1244905343',
#      'kilometers_per_hour': '29248.1659236217',
#      'miles_per_hour': '18173.6728762637'},
#     'miss_distance': {'astronomical': '1.3975390321',
#      'lunar': '543.6426834869',
#      'kilometers': '209068862.444021627',
#      'miles': '129909367.1453153726'},
#     'orbiting_body': 'Juptr'},
#    {'close_approach_date': '2020-02-07',
#     'close_approach_date_full': '2020-Feb-07 05:31',
#     'epoch_date_close_approach': 1581053460000,
#     'relative_velocity': {'kilometers_per_second': '26.4422242785',
#      'kilometers_per_hour': '95192.0074024355',
#      'miles_per_hour': '59148.6114884744'},
#     'miss_distance': {'astronomical': '0.1395935245',
#      'lunar': '54.3018810305',
#      'kilometers': '20882893.930992815',
#      'miles': '12976028.582278247'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '4',
#    'orbit_determination_date': '2020-03-05 05:05:25',
#    'first_observation_date': '2020-02-19',
#    'last_observation_date': '2020-03-05',
#    'data_arc_in_days': 15,
#    'observations_used': 67,
#    'orbit_uncertainty': '8',
#    'minimum_orbit_intersection': '.131317',
#    'jupiter_tisserand_invariant': '2.920',
#    'epoch_osculation': '2458900.5',
#    'eccentricity': '.8314511611200111',
#    'semi_major_axis': '2.381825326552185',
#    'inclination': '12.01839527001485',
#    'ascending_node_longitude': '178.4870679063588',
#    'orbital_period': '1342.65146556781',
#    'perihelion_distance': '.4014538932053214',
#    'perihelion_argument': '212.3470635706314',
#    'aphelion_distance': '4.362196759899049',
#    'perihelion_time': '2458843.016325842457',
#    'mean_anomaly': '15.41287759885169',
#    'mean_motion': '.2681261736438469',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/54005660?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '54005660',
#   'neo_reference_id': '54005660',
#   'name': '(2020 DP3)',
#   'designation': '2020 DP3',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54005660',
#   'absolute_magnitude_h': 25.815,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0182622791,
#     'estimated_diameter_max': 0.0408356976},
#    'meters': {'estimated_diameter_min': 18.2622791356,
#     'estimated_diameter_max': 40.8356975712},
#    'miles': {'estimated_diameter_min': 0.0113476506,
#     'estimated_diameter_max': 0.0253741182},
#    'feet': {'estimated_diameter_min': 59.9156158792,
#     'estimated_diameter_max': 133.9753900196}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-02-29',
#     'close_approach_date_full': '2020-Feb-29 19:11',
#     'epoch_date_close_approach': 1583003460000,
#     'relative_velocity': {'kilometers_per_second': '7.8877003378',
#      'kilometers_per_hour': '28395.7212159164',
#      'miles_per_hour': '17643.9968855232'},
#     'miss_distance': {'astronomical': '0.0379175584',
#      'lunar': '14.7499302176',
#      'kilometers': '5672385.972240608',
#      'miles': '3524657.2026240704'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '7',
#    'orbit_determination_date': '2020-03-05 05:05:44',
#    'first_observation_date': '2020-02-26',
#    'last_observation_date': '2020-03-05',
#    'data_arc_in_days': 8,
#    'observations_used': 120,
#    'orbit_uncertainty': '7',
#    'minimum_orbit_intersection': '.0340777',
#    'jupiter_tisserand_invariant': '3.503',
#    'epoch_osculation': '2459000.5',
#    'eccentricity': '.5256301376249329',
#    'semi_major_axis': '2.15350550265944',
#    'inclination': '6.959818546565653',
#    'ascending_node_longitude': '338.2630924121208',
#    'orbital_period': '1154.296571166349',
#    'perihelion_distance': '1.021558108920508',
#    'perihelion_argument': '192.0954158340282',
#    'aphelion_distance': '3.285452896398372',
#    'perihelion_time': '2458917.151232838904',
#    'mean_anomaly': '25.99466803204291',
#    'mean_motion': '.3118782546813261',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/54005705?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '54005705',
#   'neo_reference_id': '54005705',
#   'name': '(2020 DC4)',
#   'designation': '2020 DC4',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54005705',
#   'absolute_magnitude_h': 25.653,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0196768229,
#     'estimated_diameter_max': 0.0439987136},
#    'meters': {'estimated_diameter_min': 19.6768228913,
#     'estimated_diameter_max': 43.9987135661},
#    'miles': {'estimated_diameter_min': 0.0122266071,
#     'estimated_diameter_max': 0.0273395246},
#    'feet': {'estimated_diameter_min': 64.5565076146,
#     'estimated_diameter_max': 144.3527394163}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-02-26',
#     'close_approach_date_full': '2020-Feb-26 19:17',
#     'epoch_date_close_approach': 1582744620000,
#     'relative_velocity': {'kilometers_per_second': '14.4579275485',
#      'kilometers_per_hour': '52048.5391747228',
#      'miles_per_hour': '32340.9381333159'},
#     'miss_distance': {'astronomical': '0.0718111248',
#      'lunar': '27.9345275472',
#      'kilometers': '10742791.312384176',
#      'miles': '6675260.9855505888'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '1',
#    'orbit_determination_date': '2020-02-28 15:12:11',
#    'first_observation_date': '2020-02-27',
#    'last_observation_date': '2020-02-28',
#    'data_arc_in_days': 1,
#    'observations_used': 17,
#    'orbit_uncertainty': '8',
#    'minimum_orbit_intersection': '.0718104',
#    'jupiter_tisserand_invariant': '4.715',
#    'epoch_osculation': '2458907.5',
#    'eccentricity': '.220247917662008',
#    'semi_major_axis': '1.36073264136498',
#    'inclination': '26.75635278891373',
#    'ascending_node_longitude': '337.4420367614198',
#    'orbital_period': '579.7725256268212',
#    'perihelion_distance': '1.061034110609619',
#    'perihelion_argument': '174.4559751704099',
#    'aphelion_distance': '1.660431172120341',
#    'perihelion_time': '2458900.854163519523',
#    'mean_anomaly': '4.126620402346708',
#    'mean_motion': '.62093318342532',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/54013535?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '54013535',
#   'neo_reference_id': '54013535',
#   'name': '(2020 EC)',
#   'designation': '2020 EC',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54013535',
#   'absolute_magnitude_h': 19.541,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.328363576,
#     'estimated_diameter_max': 0.7342432772},
#    'meters': {'estimated_diameter_min': 328.3635759702,
#     'estimated_diameter_max': 734.2432772042},
#    'miles': {'estimated_diameter_min': 0.2040356036,
#     'estimated_diameter_max': 0.4562374794},
#    'feet': {'estimated_diameter_min': 1077.308354586,
#     'estimated_diameter_max': 2408.9347135827}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-02-06',
#     'close_approach_date_full': '2020-Feb-06 06:03',
#     'epoch_date_close_approach': 1580968980000,
#     'relative_velocity': {'kilometers_per_second': '25.3049638508',
#      'kilometers_per_hour': '91097.8698629909',
#      'miles_per_hour': '56604.6736379234'},
#     'miss_distance': {'astronomical': '0.3857633076',
#      'lunar': '150.0619266564',
#      'kilometers': '57709369.141114812',
#      'miles': '35858939.1831839256'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '4',
#    'orbit_determination_date': '2020-03-15 07:08:58',
#    'first_observation_date': '2020-03-03',
#    'last_observation_date': '2020-03-15',
#    'data_arc_in_days': 12,
#    'observations_used': 35,
#    'orbit_uncertainty': '9',
#    'minimum_orbit_intersection': '.209208',
#    'jupiter_tisserand_invariant': '3.013',
#    'epoch_osculation': '2458913.5',
#    'eccentricity': '.6949381021551335',
#    'semi_major_axis': '2.515021078387371',
#    'inclination': '19.19874393561383',
#    'ascending_node_longitude': '250.1957135194077',
#    'orbital_period': '1456.836690705583',
#    'perihelion_distance': '.7672371032926942',
#    'perihelion_argument': '174.2172783430186',
#    'aphelion_distance': '4.262805053482048',
#    'perihelion_time': '2458852.101525252537',
#    'mean_anomaly': '15.17222283740082',
#    'mean_motion': '.2471107450112633',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/54016283?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '54016283',
#   'neo_reference_id': '54016283',
#   'name': '(2020 FK2)',
#   'designation': '2020 FK2',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016283',
#   'absolute_magnitude_h': 23.141,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0625683895,
#     'estimated_diameter_max': 0.1399071722},
#    'meters': {'estimated_diameter_min': 62.5683895221,
#     'estimated_diameter_max': 139.9071722141},
#    'miles': {'estimated_diameter_min': 0.0388781828,
#     'estimated_diameter_max': 0.0869342595},
#    'feet': {'estimated_diameter_min': 205.2768750797,
#     'estimated_diameter_max': 459.013046887}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-03-11',
#     'close_approach_date_full': '2020-Mar-11 05:46',
#     'epoch_date_close_approach': 1583905560000,
#     'relative_velocity': {'kilometers_per_second': '22.8886819278',
#      'kilometers_per_hour': '82399.2549402456',
#      'miles_per_hour': '51199.6926043987'},
#     'miss_distance': {'astronomical': '0.1573675045',
#      'lunar': '61.2159592505',
#      'kilometers': '23541843.480415415',
#      'miles': '14628223.219006127'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '1',
#    'orbit_determination_date': '2020-03-21 16:42:11',
#    'first_observation_date': '2020-03-18',
#    'last_observation_date': '2020-03-21',
#    'data_arc_in_days': 3,
#    'observations_used': 23,
#    'orbit_uncertainty': '9',
#    'minimum_orbit_intersection': '.0851773',
#    'jupiter_tisserand_invariant': '3.734',
#    'epoch_osculation': '2458927.5',
#    'eccentricity': '.6587779111268063',
#    'semi_major_axis': '1.822762890259999',
#    'inclination': '9.147234271499233',
#    'ascending_node_longitude': '21.56985097640062',
#    'orbital_period': '898.863393755479',
#    'perihelion_distance': '.621966960935057',
#    'perihelion_argument': '54.59046671981903',
#    'aphelion_distance': '3.023558819584942',
#    'perihelion_time': '2458871.658653967875',
#    'mean_anomaly': '22.36478280373008',
#    'mean_motion': '.4005057970999452',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/54016308?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '54016308',
#   'neo_reference_id': '54016308',
#   'name': '(2020 FX2)',
#   'designation': '2020 FX2',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016308',
#   'absolute_magnitude_h': 23.585,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0509982151,
#     'estimated_diameter_max': 0.1140354758},
#    'meters': {'estimated_diameter_min': 50.998215127,
#     'estimated_diameter_max': 114.0354757552},
#    'miles': {'estimated_diameter_min': 0.0316888119,
#     'estimated_diameter_max': 0.0708583376},
#    'feet': {'estimated_diameter_min': 167.3169841173,
#     'estimated_diameter_max': 374.1321502766}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-03-17',
#     'close_approach_date_full': '2020-Mar-17 03:42',
#     'epoch_date_close_approach': 1584416520000,
#     'relative_velocity': {'kilometers_per_second': '17.6412382711',
#      'kilometers_per_hour': '63508.4577758642',
#      'miles_per_hour': '39461.6858885641'},
#     'miss_distance': {'astronomical': '0.0830297775',
#      'lunar': '32.2985834475',
#      'kilometers': '12421077.860573925',
#      'miles': '7718099.889513165'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '2',
#    'orbit_determination_date': '2020-04-01 05:54:39',
#    'first_observation_date': '2020-03-22',
#    'last_observation_date': '2020-03-31',
#    'data_arc_in_days': 9,
#    'observations_used': 23,
#    'orbit_uncertainty': '9',
#    'minimum_orbit_intersection': '.0568822',
#    'jupiter_tisserand_invariant': '4.361',
#    'epoch_osculation': '2458931.5',
#    'eccentricity': '.3431373247700218',
#    'semi_major_axis': '1.493186207310123',
#    'inclination': '29.45598945459667',
#    'ascending_node_longitude': '176.176436819757',
#    'orbital_period': '666.4527761116287',
#    'perihelion_distance': '.9808182867502324',
#    'perihelion_argument': '316.3324256366288',
#    'aphelion_distance': '2.005554127870014',
#    'perihelion_time': '2458889.779800528263',
#    'mean_anomaly': '22.53613811537284',
#    'mean_motion': '.5401733069526612',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/54016449?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '54016449',
#   'neo_reference_id': '54016449',
#   'name': '(2020 GR)',
#   'designation': '2020 GR',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016449',
#   'absolute_magnitude_h': 25.609,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0200795963,
#     'estimated_diameter_max': 0.0448993422},
#    'meters': {'estimated_diameter_min': 20.0795962783,
#     'estimated_diameter_max': 44.899342239},
#    'miles': {'estimated_diameter_min': 0.0124768788,
#     'estimated_diameter_max': 0.0278991492},
#    'feet': {'estimated_diameter_min': 65.8779426537,
#     'estimated_diameter_max': 147.3075579914}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-03-25',
#     'close_approach_date_full': '2020-Mar-25 01:12',
#     'epoch_date_close_approach': 1585098720000,
#     'relative_velocity': {'kilometers_per_second': '7.8251116446',
#      'kilometers_per_hour': '28170.4019207105',
#      'miles_per_hour': '17503.9922378992'},
#     'miss_distance': {'astronomical': '0.0676338284',
#      'lunar': '26.3095592476',
#      'kilometers': '10117876.668585508',
#      'miles': '6286957.0317876904'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '2',
#    'orbit_determination_date': '2020-04-16 06:09:03',
#    'first_observation_date': '2020-04-02',
#    'last_observation_date': '2020-04-15',
#    'data_arc_in_days': 13,
#    'observations_used': 22,
#    'orbit_uncertainty': '8',
#    'minimum_orbit_intersection': '.0642435',
#    'jupiter_tisserand_invariant': '4.158',
#    'epoch_osculation': '2458943.5',
#    'eccentricity': '.3786606054040539',
#    'semi_major_axis': '1.663180899228377',
#    'inclination': '10.41635093360987',
#    'ascending_node_longitude': '191.3841857271919',
#    'orbital_period': '783.4434607332208',
#    'perihelion_distance': '1.033399813030101',
#    'perihelion_argument': '329.2216374079899',
#    'aphelion_distance': '2.292961985426653',
#    'perihelion_time': '2458912.710065096153',
#    'mean_anomaly': '14.14827887517385',
#    'mean_motion': '.4595098664338557',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'AMO',
#     'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor',
#     'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/54016454?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '54016454',
#   'neo_reference_id': '54016454',
#   'name': '(2020 GU)',
#   'designation': '2020 GU',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016454',
#   'absolute_magnitude_h': 24.774,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0294954466,
#     'estimated_diameter_max': 0.0659538237},
#    'meters': {'estimated_diameter_min': 29.4954466177,
#     'estimated_diameter_max': 65.9538236638},
#    'miles': {'estimated_diameter_min': 0.0183276152,
#     'estimated_diameter_max': 0.0409817934},
#    'feet': {'estimated_diameter_min': 96.7698410811,
#     'estimated_diameter_max': 216.3839428291}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2020-03-26',
#     'close_approach_date_full': '2020-Mar-26 22:14',
#     'epoch_date_close_approach': 1585260840000,
#     'relative_velocity': {'kilometers_per_second': '11.2818345877',
#      'kilometers_per_hour': '40614.6045156592',
#      'miles_per_hour': '25236.3357891883'},
#     'miss_distance': {'astronomical': '0.0630102364',
#      'lunar': '24.5109819596',
#      'kilometers': '9426197.153636468',
#      'miles': '5857167.3108125384'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '3',
#    'orbit_determination_date': '2020-04-17 06:30:09',
#    'first_observation_date': '2020-04-02',
#    'last_observation_date': '2020-04-16',
#    'data_arc_in_days': 14,
#    'observations_used': 25,
#    'orbit_uncertainty': '8',
#    'minimum_orbit_intersection': '.0397769',
#    'jupiter_tisserand_invariant': '4.016',
#    'epoch_osculation': '2458943.5',
#    'eccentricity': '.4654046180620224',
#    'semi_major_axis': '1.731106495775053',
#    'inclination': '8.270325485406854',
#    'ascending_node_longitude': '194.8011152402306',
#    'orbital_period': '831.9248668917677',
#    'perihelion_distance': '.9254415382841784',
#    'perihelion_argument': '302.1814563052077',
#    'aphelion_distance': '2.536771453265927',
#    'perihelion_time': '2458898.024146491251',
#    'mean_anomaly': '19.67882908022213',
#    'mean_motion': '.4327313851610539',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/54016643?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '54016643',
#   'neo_reference_id': '54016643',
#   'name': '(2020 HY2)',
#   'designation': '2020 HY2',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016643',
#   'absolute_magnitude_h': 24.947,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0272367307,
#     'estimated_diameter_max': 0.0609031813},
#    'meters': {'estimated_diameter_min': 27.2367306877,
#     'estimated_diameter_max': 60.9031813025},
#    'miles': {'estimated_diameter_min': 0.0169241146,
#     'estimated_diameter_max': 0.0378434707},
#    'feet': {'estimated_diameter_min': 89.3593555094,
#     'estimated_diameter_max': 199.8135933445}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2018-11-06',
#     'close_approach_date_full': '2018-Nov-06 20:46',
#     'epoch_date_close_approach': 1541537160000,
#     'relative_velocity': {'kilometers_per_second': '10.3167869551',
#      'kilometers_per_hour': '37140.4330384259',
#      'miles_per_hour': '23077.6207399041'},
#     'miss_distance': {'astronomical': '1.2511530813',
#      'lunar': '486.6985486257',
#      'kilometers': '187169836.006416831',
#      'miles': '116301943.1016250278'},
#     'orbiting_body': 'Juptr'},
#    {'close_approach_date': '2020-04-18',
#     'close_approach_date_full': '2020-Apr-18 08:50',
#     'epoch_date_close_approach': 1587199800000,
#     'relative_velocity': {'kilometers_per_second': '37.6811128528',
#      'kilometers_per_hour': '135652.0062701725',
#      'miles_per_hour': '84288.8813404858'},
#     'miss_distance': {'astronomical': '0.0183225763',
#      'lunar': '7.1274821807',
#      'kilometers': '2741018.387392481',
#      'miles': '1703189.8479629978'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '1',
#    'orbit_determination_date': '2020-04-22 03:42:11',
#    'first_observation_date': '2020-04-19',
#    'last_observation_date': '2020-04-22',
#    'data_arc_in_days': 3,
#    'observations_used': 24,
#    'orbit_uncertainty': '9',
#    'minimum_orbit_intersection': '.00662723',
#    'jupiter_tisserand_invariant': '2.671',
#    'epoch_osculation': '2458959.5',
#    'eccentricity': '.9462385721220348',
#    'semi_major_axis': '2.314433250797457',
#    'inclination': '11.39410838624164',
#    'ascending_node_longitude': '205.9024839089144',
#    'orbital_period': '1286.072396747414',
#    'perihelion_distance': '.1244272362911121',
#    'perihelion_argument': '218.6158276532884',
#    'aphelion_distance': '4.504439265303803',
#    'perihelion_time': '2458923.200066788815',
#    'mean_anomaly': '10.16115110554943',
#    'mean_motion': '.2799220330911933',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False},
#  {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/54017454?api_key=EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5,EtSDBzChRyQL87tRvf6vAemUDFCJujscffspj9i5'},
#   'id': '54017454',
#   'neo_reference_id': '54017454',
#   'name': '(2020 LM1)',
#   'designation': '2020 LM1',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54017454',
#   'absolute_magnitude_h': 21.529,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1314483008,
#     'estimated_diameter_max': 0.2939273362},
#    'meters': {'estimated_diameter_min': 131.4483008443,
#     'estimated_diameter_max': 293.9273362148},
#    'miles': {'estimated_diameter_min': 0.0816781621,
#     'estimated_diameter_max': 0.1826379228},
#    'feet': {'estimated_diameter_min': 431.2608433421,
#     'estimated_diameter_max': 964.3285617469}},
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_data': [{'close_approach_date': '2020-06-11',
#     'close_approach_date_full': '2020-Jun-11 05:13',
#     'epoch_date_close_approach': 1591852380000,
#     'relative_velocity': {'kilometers_per_second': '17.1852821171',
#      'kilometers_per_hour': '61867.0156215812',
#      'miles_per_hour': '38441.7575677542'},
#     'miss_distance': {'astronomical': '0.1146929035',
#      'lunar': '44.6155394615',
#      'kilometers': '17157814.067715545',
#      'miles': '10661371.287322721'},
#     'orbiting_body': 'Earth'}],
#   'orbital_data': {'orbit_id': '3',
#    'orbit_determination_date': '2020-06-23 06:12:50',
#    'first_observation_date': '2020-06-15',
#    'last_observation_date': '2020-06-22',
#    'data_arc_in_days': 7,
#    'observations_used': 35,
#    'orbit_uncertainty': '9',
#    'minimum_orbit_intersection': '.027973',
#    'jupiter_tisserand_invariant': '3.229',
#    'epoch_osculation': '2459017.5',
#    'eccentricity': '.60304894881334',
#    'semi_major_axis': '2.36202827641467',
#    'inclination': '17.27528745249329',
#    'ascending_node_longitude': '75.37222119981672',
#    'orbital_period': '1325.946695778187',
#    'perihelion_distance': '.9376096072554179',
#    'perihelion_argument': '135.0353638511596',
#    'aphelion_distance': '3.786446945573922',
#    'perihelion_time': '2458977.244505873983',
#    'mean_anomaly': '10.92953278703327',
#    'mean_motion': '.2715041269352981',
#    'equinox': 'J2000',
#    'orbit_class': {'orbit_class_type': 'APO',
#     'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo',
#     'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}},
#   'is_sentry_object': False}]

# %% [markdown]
# Normalizar y crea los dataframes

# %%
df_datos = {}
for k in dict_datos:
    normalizados = pd.json_normalize(dict_datos[k])
    df_datos[k] = normalizados  # esto ya es un DF

# %%
df_datos[9]
# Out:
#           id neo_reference_id         name designation  \
# 0    3986728          3986728    (2020 BL)     2020 BL
# 1    3986733          3986733    (2020 BQ)     2020 BQ
# 2    3986736          3986736    (2020 BT)     2020 BT
# 3    3986774          3986774   (2020 BX1)    2020 BX1
# 4    3989254          3989254  (2020 BE11)   2020 BE11
# 5    3989292          3989292  (2020 BE13)   2020 BE13
# 6    3989293          3989293  (2020 BG13)   2020 BG13
# 7    3989331          3989331  (2020 BH14)   2020 BH14
# 8    3991546          3991546   (2020 CZ1)    2020 CZ1
# 9    3991649          3991649   (2020 CB3)    2020 CB3
# 10   3994620          3994620   (2020 DS2)    2020 DS2
# 11  54005660         54005660   (2020 DP3)    2020 DP3
# 12  54005705         54005705   (2020 DC4)    2020 DC4
# 13  54013535         54013535    (2020 EC)     2020 EC
# 14  54016283         54016283   (2020 FK2)    2020 FK2
# 15  54016308         54016308   (2020 FX2)    2020 FX2
# 16  54016449         54016449    (2020 GR)     2020 GR
# 17  54016454         54016454    (2020 GU)     2020 GU
# 18  54016643         54016643   (2020 HY2)    2020 HY2
# 19  54017454         54017454   (2020 LM1)    2020 LM1
#
#                                       nasa_jpl_url  absolute_magnitude_h  \
# 0    http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986728                26.931
# 1    http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986733                24.668
# 2    http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986736                24.408
# 3    http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986774                25.126
# 4    http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989254                22.430
# 5    http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989292                26.250
# 6    http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989293                27.764
# 7    http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989331                18.929
# 8    http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991546                25.475
# 9    http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3991649                24.519
# 10   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3994620                21.683
# 11  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54005660                25.815
# 12  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54005705                25.653
# 13  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54013535                19.541
# 14  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016283                23.141
# 15  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016308                23.585
# 16  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016449                25.609
# 17  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016454                24.774
# 18  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016643                24.947
# 19  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54017454                21.529
#
#     is_potentially_hazardous_asteroid  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# 5                               False
# 6                               False
# 7                               False
# 8                               False
# 9                               False
# 10                              False
# 11                              False
# 12                              False
# 13                              False
# 14                              False
# 15                              False
# 16                              False
# 17                              False
# 18                              False
# 19                               True
#
#                                   close_approach_data  is_sentry_object  \
# 0   [{'close_approach_date': '1962-03-20', 'close_...             False
# 1   [{'close_approach_date': '2020-01-18', 'close_...             False
# 2   [{'close_approach_date': '2020-01-19', 'close_...             False
# 3   [{'close_approach_date': '1973-05-04', 'close_...             False
# 4   [{'close_approach_date': '2020-01-05', 'close_...             False
# 5   [{'close_approach_date': '2020-01-21', 'close_...             False
# 6   [{'close_approach_date': '2020-01-28', 'close_...             False
# 7                                                  []             False
# 8   [{'close_approach_date': '2020-01-15', 'close_...             False
# 9   [{'close_approach_date': '1960-06-28', 'close_...             False
# 10  [{'close_approach_date': '2017-10-19', 'close_...             False
# 11  [{'close_approach_date': '2020-02-29', 'close_...             False
# 12  [{'close_approach_date': '2020-02-26', 'close_...             False
# 13  [{'close_approach_date': '2020-02-06', 'close_...             False
# 14  [{'close_approach_date': '2020-03-11', 'close_...             False
# 15  [{'close_approach_date': '2020-03-17', 'close_...             False
# 16  [{'close_approach_date': '2020-03-25', 'close_...             False
# 17  [{'close_approach_date': '2020-03-26', 'close_...             False
# 18  [{'close_approach_date': '2018-11-06', 'close_...             False
# 19  [{'close_approach_date': '2020-06-11', 'close_...             False
#
#                                            links.self  ...  \
# 0   http://www.neowsapp.com/rest/v1/neo/3986728?ap...  ...
# 1   http://www.neowsapp.com/rest/v1/neo/3986733?ap...  ...
# 2   http://www.neowsapp.com/rest/v1/neo/3986736?ap...  ...
# 3   http://www.neowsapp.com/rest/v1/neo/3986774?ap...  ...
# 4   http://www.neowsapp.com/rest/v1/neo/3989254?ap...  ...
# 5   http://www.neowsapp.com/rest/v1/neo/3989292?ap...  ...
# 6   http://www.neowsapp.com/rest/v1/neo/3989293?ap...  ...
# 7   http://www.neowsapp.com/rest/v1/neo/3989331?ap...  ...
# 8   http://www.neowsapp.com/rest/v1/neo/3991546?ap...  ...
# 9   http://www.neowsapp.com/rest/v1/neo/3991649?ap...  ...
# 10  http://www.neowsapp.com/rest/v1/neo/3994620?ap...  ...
# 11  http://www.neowsapp.com/rest/v1/neo/54005660?a...  ...
# 12  http://www.neowsapp.com/rest/v1/neo/54005705?a...  ...
# 13  http://www.neowsapp.com/rest/v1/neo/54013535?a...  ...
# 14  http://www.neowsapp.com/rest/v1/neo/54016283?a...  ...
# 15  http://www.neowsapp.com/rest/v1/neo/54016308?a...  ...
# 16  http://www.neowsapp.com/rest/v1/neo/54016449?a...  ...
# 17  http://www.neowsapp.com/rest/v1/neo/54016454?a...  ...
# 18  http://www.neowsapp.com/rest/v1/neo/54016643?a...  ...
# 19  http://www.neowsapp.com/rest/v1/neo/54017454?a...  ...
#
#     orbital_data.perihelion_distance  orbital_data.perihelion_argument  \
# 0                  1.002518306912191                 8.227363955287679
# 1                  1.000552891224993                 18.81688784499064
# 2                  1.020229637582618                 315.3927520659097
# 3                  .8353158022179638                 96.89180428358247
# 4                  .9247004254664548                 325.8282467115266
# 5                  .8921651498643854                 294.7222698660501
# 6                   .967332111691493                 335.8728473346216
# 7                   .777620074648398                 32.74065680558773
# 8                  .9736214654025419                  83.4235788605328
# 9                  .6705160773044087                 94.53171874706973
# 10                 .4014538932053214                 212.3470635706314
# 11                 1.021558108920508                 192.0954158340282
# 12                 1.061034110609619                 174.4559751704099
# 13                 .7672371032926942                 174.2172783430186
# 14                  .621966960935057                 54.59046671981903
# 15                 .9808182867502324                 316.3324256366288
# 16                 1.033399813030101                 329.2216374079899
# 17                 .9254415382841784                 302.1814563052077
# 18                 .1244272362911121                 218.6158276532884
# 19                 .9376096072554179                 135.0353638511596
#
#     orbital_data.aphelion_distance  orbital_data.perihelion_time  \
# 0                3.065350481307789          2458868.587550769741
# 1                1.950771757536759          2458883.330789923232
# 2                 3.64118230369959          2458850.702997023009
# 3                2.591830449256688          2458910.238048311456
# 4                2.665445953427422          2458824.477062446950
# 5                3.376253943345804          2458838.032054758972
# 6                2.088592653703688          2458857.126829566205
# 7                3.855992075656786          2458683.064344891524
# 8                4.076745252450549          2458848.797551855900
# 9                 3.61571665469196          2458848.223181469567
# 10               4.362196759899049          2458843.016325842457
# 11               3.285452896398372          2458917.151232838904
# 12               1.660431172120341          2458900.854163519523
# 13               4.262805053482048          2458852.101525252537
# 14               3.023558819584942          2458871.658653967875
# 15               2.005554127870014          2458889.779800528263
# 16               2.292961985426653          2458912.710065096153
# 17               2.536771453265927          2458898.024146491251
# 18               4.504439265303803          2458923.200066788815
# 19               3.786446945573922          2458977.244505873983
#
#     orbital_data.mean_anomaly  orbital_data.mean_motion  orbital_data.equinox  \
# 0           44.82129986271848         .3397806660725483                 J2000
# 1            352.945325435686         .5498238694985217                 J2000
# 2           5.483682343510867         .2769955810929694                 J2000
# 3           338.5849918324493         .4393899409081805                 J2000
# 4           72.13567459545385         .4098083783751952                 J2000
# 5           12.47650668203847         .3161174620529474                 J2000
# 6           74.81746158526329         .5218372542009987                 J2000
# 7           88.72076032936167         .2794921077754906                 J2000
# 8           8.278013781201848         .2456205479734863                 J2000
# 9           16.42270130504433         .3141488286148064                 J2000
# 10          15.41287759885169         .2681261736438469                 J2000
# 11          25.99466803204291         .3118782546813261                 J2000
# 12          4.126620402346708           .62093318342532                 J2000
# 13          15.17222283740082         .2471107450112633                 J2000
# 14          22.36478280373008         .4005057970999452                 J2000
# 15          22.53613811537284         .5401733069526612                 J2000
# 16          14.14827887517385         .4595098664338557                 J2000
# 17          19.67882908022213         .4327313851610539                 J2000
# 18          10.16115110554943         .2799220330911933                 J2000
# 19          10.92953278703327         .2715041269352981                 J2000
#
#     orbital_data.orbit_class.orbit_class_type  \
# 0                                         APO
# 1                                         APO
# 2                                         AMO
# 3                                         APO
# 4                                         APO
# 5                                         APO
# 6                                         APO
# 7                                         APO
# 8                                         APO
# 9                                         APO
# 10                                        APO
# 11                                        AMO
# 12                                        AMO
# 13                                        APO
# 14                                        APO
# 15                                        APO
# 16                                        AMO
# 17                                        APO
# 18                                        APO
# 19                                        APO
#
#      orbital_data.orbit_class.orbit_class_description  \
# 0   Near-Earth asteroid orbits which cross the Ear...
# 1   Near-Earth asteroid orbits which cross the Ear...
# 2   Near-Earth asteroid orbits similar to that of ...
# 3   Near-Earth asteroid orbits which cross the Ear...
# 4   Near-Earth asteroid orbits which cross the Ear...
# 5   Near-Earth asteroid orbits which cross the Ear...
# 6   Near-Earth asteroid orbits which cross the Ear...
# 7   Near-Earth asteroid orbits which cross the Ear...
# 8   Near-Earth asteroid orbits which cross the Ear...
# 9   Near-Earth asteroid orbits which cross the Ear...
# 10  Near-Earth asteroid orbits which cross the Ear...
# 11  Near-Earth asteroid orbits similar to that of ...
# 12  Near-Earth asteroid orbits similar to that of ...
# 13  Near-Earth asteroid orbits which cross the Ear...
# 14  Near-Earth asteroid orbits which cross the Ear...
# 15  Near-Earth asteroid orbits which cross the Ear...
# 16  Near-Earth asteroid orbits similar to that of ...
# 17  Near-Earth asteroid orbits which cross the Ear...
# 18  Near-Earth asteroid orbits which cross the Ear...
# 19  Near-Earth asteroid orbits which cross the Ear...
#
#            orbital_data.orbit_class.orbit_class_range
# 0   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 1   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 2                  1.017 AU < q (perihelion) < 1.3 AU
# 3   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 4   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 5   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 6   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 7   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 8   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 9   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 10  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 11                 1.017 AU < q (perihelion) < 1.3 AU
# 12                 1.017 AU < q (perihelion) < 1.3 AU
# 13  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 14  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 15  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 16                 1.017 AU < q (perihelion) < 1.3 AU
# 17  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 18  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 19  a (semi-major axis) > 1.0 AU; q (perihelion) <...
#
# [20 rows x 43 columns]

# %% [markdown]
# Crea una lista con sólo los dataframes

# %%
df_lista = []
for k in df_datos:
    df_lista.append(df_datos[k])
df_lista[0]
# Out:
#          id neo_reference_id         name designation  \
# 0   3092128          3092128   (1994 TA2)    1994 TA2
# 1   3092129          3092129   (1994 TE2)    1994 TE2
# 2   3092130          3092130    (1994 US)     1994 US
# 3   3092134          3092134   (1995 BK2)    1995 BK2
# 4   3092136          3092136   (1995 DV1)    1995 DV1
# 5   3006207          3006207    (1995 HM)     1995 HM
# 6   3007950          3007950    (1995 LA)     1995 LA
# 7   3092139          3092139    (1995 NA)     1995 NA
# 8   3092141          3092141   (1995 SC1)    1995 SC1
# 9   3092142          3092142   (1995 UC2)    1995 UC2
# 10  3092143          3092143   (1996 AP1)    1996 AP1
# 11  3008375          3008375    (1996 BT)     1996 BT
# 12  3009014          3009014    (1996 HN)     1996 HN
# 13  3009117          3009117    (1996 MQ)     1996 MQ
# 14  3092151          3092151   (1996 TC1)    1996 TC1
# 15  3092155          3092155   (1996 VZ4)    1996 VZ4
# 16  3092157          3092157  (1997 EN23)   1997 EN23
# 17  3010396          3010396  (1997 TZ16)   1997 TZ16
# 18  3092161          3092161  (1997 TC25)   1997 TC25
# 19  3092162          3092162  (1997 UZ10)   1997 UZ10
#
#                                      nasa_jpl_url  absolute_magnitude_h  \
# 0   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092128                  20.3
# 1   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092129                  22.7
# 2   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092130                  21.0
# 3   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092134                  22.6
# 4   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092136                  23.0
# 5   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3006207                  23.0
# 6   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3007950                  24.0
# 7   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092139                  23.2
# 8   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092141                  22.7
# 9   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092142                  21.4
# 10  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092143                  24.7
# 11  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3008375                  23.0
# 12  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3009014                  21.5
# 13  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3009117                  24.5
# 14  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092151                  23.9
# 15  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092155                  24.2
# 16  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092157                  22.8
# 17  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3010396                  24.5
# 18  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092161                  24.6
# 19  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092162                  23.0
#
#     is_potentially_hazardous_asteroid  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# 5                               False
# 6                               False
# 7                               False
# 8                               False
# 9                               False
# 10                              False
# 11                              False
# 12                              False
# 13                              False
# 14                              False
# 15                              False
# 16                              False
# 17                              False
# 18                              False
# 19                              False
#
#                                   close_approach_data  is_sentry_object  \
# 0   [{'close_approach_date': '1994-08-21', 'close_...             False
# 1                                                  []             False
# 2   [{'close_approach_date': '1994-09-12', 'close_...             False
# 3   [{'close_approach_date': '1995-01-29', 'close_...             False
# 4   [{'close_approach_date': '1995-01-24', 'close_...             False
# 5   [{'close_approach_date': '1995-05-27', 'close_...             False
# 6   [{'close_approach_date': '1995-06-04', 'close_...             False
# 7   [{'close_approach_date': '1995-07-10', 'close_...             False
# 8   [{'close_approach_date': '1995-09-07', 'close_...             False
# 9                                                  []             False
# 10  [{'close_approach_date': '1996-01-06', 'close_...             False
# 11  [{'close_approach_date': '1996-01-29', 'close_...             False
# 12  [{'close_approach_date': '1996-05-01', 'close_...             False
# 13  [{'close_approach_date': '1996-06-30', 'close_...             False
# 14  [{'close_approach_date': '1996-09-25', 'close_...              True
# 15  [{'close_approach_date': '1996-11-13', 'close_...             False
# 16  [{'close_approach_date': '1997-03-17', 'close_...             False
# 17  [{'close_approach_date': '1997-10-16', 'close_...             False
# 18  [{'close_approach_date': '1991-08-09', 'close_...              True
# 19  [{'close_approach_date': '1997-10-30', 'close_...             False
#
#                                            links.self  ...  \
# 0   http://www.neowsapp.com/rest/v1/neo/3092128?ap...  ...
# 1   http://www.neowsapp.com/rest/v1/neo/3092129?ap...  ...
# 2   http://www.neowsapp.com/rest/v1/neo/3092130?ap...  ...
# 3   http://www.neowsapp.com/rest/v1/neo/3092134?ap...  ...
# 4   http://www.neowsapp.com/rest/v1/neo/3092136?ap...  ...
# 5   http://www.neowsapp.com/rest/v1/neo/3006207?ap...  ...
# 6   http://www.neowsapp.com/rest/v1/neo/3007950?ap...  ...
# 7   http://www.neowsapp.com/rest/v1/neo/3092139?ap...  ...
# 8   http://www.neowsapp.com/rest/v1/neo/3092141?ap...  ...
# 9   http://www.neowsapp.com/rest/v1/neo/3092142?ap...  ...
# 10  http://www.neowsapp.com/rest/v1/neo/3092143?ap...  ...
# 11  http://www.neowsapp.com/rest/v1/neo/3008375?ap...  ...
# 12  http://www.neowsapp.com/rest/v1/neo/3009014?ap...  ...
# 13  http://www.neowsapp.com/rest/v1/neo/3009117?ap...  ...
# 14  http://www.neowsapp.com/rest/v1/neo/3092151?ap...  ...
# 15  http://www.neowsapp.com/rest/v1/neo/3092155?ap...  ...
# 16  http://www.neowsapp.com/rest/v1/neo/3092157?ap...  ...
# 17  http://www.neowsapp.com/rest/v1/neo/3010396?ap...  ...
# 18  http://www.neowsapp.com/rest/v1/neo/3092161?ap...  ...
# 19  http://www.neowsapp.com/rest/v1/neo/3092162?ap...  ...
#
#     orbital_data.perihelion_argument  orbital_data.aphelion_distance  \
# 0                  119.2555022982426               4.017794307729294
# 1                   185.076237209411               3.238264525611692
# 2                  121.3652698045077               4.296351145061368
# 3                  349.5694348355665               3.778690206917434
# 4                   284.035975525906                4.58122325569529
# 5                  209.0541426446876               1.780588291129619
# 6                   17.6421578008063               3.229806178341759
# 7                  33.71767762979477               2.342698240536675
# 8                  341.5319219166341               3.125453496530098
# 9                   272.677945470292                2.28090139509396
# 10                 323.8357620427234               2.865815068770662
# 11                 327.8866413021353               2.203117080343397
# 12                 25.13643836712958               3.110678910004471
# 13                 28.20993780252967               3.785690422549861
# 14                 258.8055087896815               3.200513528028043
# 15                 15.30264363850654               2.189423593389609
# 16                 352.8859987577055               5.309798201518714
# 17                 66.85571520199653               3.202681500436289
# 18                 321.5242028262194                4.20893401730337
# 19                 358.8045951992647               4.539983851300455
#
#     orbital_data.perihelion_time  orbital_data.mean_anomaly  \
# 0           2458938.860826509679          14.23047711609944
# 1           2449639.559120815319          359.3972999898663
# 2           2449599.393154212242          13.30456128228865
# 3           2449738.388408613994          3.393655488565221
# 4           2449721.531724521250          11.72991300130177
# 5           2458897.840254689806          57.37253084914418
# 6           2458928.660783013178          22.89910686889566
# 7           2449931.293002066728          347.9278290317616
# 8           2458980.550076299867          6.375722386683323
# 9           2449902.777522706229          48.81056941678496
# 10          2450070.066354054859           10.9361433458784
# 11          2450156.067286403417          322.2008607009153
# 12          2458573.886710594906          128.7454591299163
# 13          2450275.145913139191          356.6610759619622
# 14          2450304.285203647679          22.97355098227857
# 15          2450413.742953077443           354.075979303701
# 16          2450522.380053416901          359.5144827352368
# 17          2450777.631631737087          344.0166522626355
# 18          2450700.019271214234          8.142326319432071
# 19          2450752.054460903554          .5096556243882723
#
#     orbital_data.mean_motion  orbital_data.equinox  \
# 0          .2308674226193818                 J2000
# 1          .2926977405355879                 J2000
# 2          .2177261992625065                 J2000
# 3          .2588286492963218                 J2000
# 4          .2133942332943736                 J2000
# 5          .5588610284955301                 J2000
# 6          .3187549618350665                 J2000
# 7          .4505717925215179                 J2000
# 8          .3195863043145763                 J2000
# 9           .436891220093867                 J2000
# 10         .3715524528038897                 J2000
# 11         .7475018334487996                 J2000
# 12         .3017849240220578                 J2000
# 13         .2640318655748277                 J2000
# 14         .3879697710279821                 J2000
# 15          .483871877873462                 J2000
# 16         .1685792568686597                 J2000
# 17         .3464726292028132                 J2000
# 18         .2361413637751563                 J2000
# 19         .2084021576792346                 J2000
#
#     orbital_data.orbit_class.orbit_class_type  \
# 0                                         AMO
# 1                                         AMO
# 2                                         AMO
# 3                                         AMO
# 4                                         APO
# 5                                         AMO
# 6                                         APO
# 7                                         AMO
# 8                                         AMO
# 9                                         AMO
# 10                                        APO
# 11                                        APO
# 12                                        AMO
# 13                                        AMO
# 14                                        APO
# 15                                        AMO
# 16                                        AMO
# 17                                        APO
# 18                                        APO
# 19                                        AMO
#
#      orbital_data.orbit_class.orbit_class_description  \
# 0   Near-Earth asteroid orbits similar to that of ...
# 1   Near-Earth asteroid orbits similar to that of ...
# 2   Near-Earth asteroid orbits similar to that of ...
# 3   Near-Earth asteroid orbits similar to that of ...
# 4   Near-Earth asteroid orbits which cross the Ear...
# 5   Near-Earth asteroid orbits similar to that of ...
# 6   Near-Earth asteroid orbits which cross the Ear...
# 7   Near-Earth asteroid orbits similar to that of ...
# 8   Near-Earth asteroid orbits similar to that of ...
# 9   Near-Earth asteroid orbits similar to that of ...
# 10  Near-Earth asteroid orbits which cross the Ear...
# 11  Near-Earth asteroid orbits which cross the Ear...
# 12  Near-Earth asteroid orbits similar to that of ...
# 13  Near-Earth asteroid orbits similar to that of ...
# 14  Near-Earth asteroid orbits which cross the Ear...
# 15  Near-Earth asteroid orbits similar to that of ...
# 16  Near-Earth asteroid orbits similar to that of ...
# 17  Near-Earth asteroid orbits which cross the Ear...
# 18  Near-Earth asteroid orbits which cross the Ear...
# 19  Near-Earth asteroid orbits similar to that of ...
#
#            orbital_data.orbit_class.orbit_class_range  \
# 0                  1.017 AU < q (perihelion) < 1.3 AU
# 1                  1.017 AU < q (perihelion) < 1.3 AU
# 2                  1.017 AU < q (perihelion) < 1.3 AU
# 3                  1.017 AU < q (perihelion) < 1.3 AU
# 4   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 5                  1.017 AU < q (perihelion) < 1.3 AU
# 6   a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 7                  1.017 AU < q (perihelion) < 1.3 AU
# 8                  1.017 AU < q (perihelion) < 1.3 AU
# 9                  1.017 AU < q (perihelion) < 1.3 AU
# 10  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 11  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 12                 1.017 AU < q (perihelion) < 1.3 AU
# 13                 1.017 AU < q (perihelion) < 1.3 AU
# 14  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 15                 1.017 AU < q (perihelion) < 1.3 AU
# 16                 1.017 AU < q (perihelion) < 1.3 AU
# 17  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 18  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 19                 1.017 AU < q (perihelion) < 1.3 AU
#
#                                           sentry_data
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  http://www.neowsapp.com/rest/v1/neo/sentry/309...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  http://www.neowsapp.com/rest/v1/neo/sentry/309...
# 19                                                NaN
#
# [20 rows x 44 columns]

# %% [markdown]
# Concatena los dataframes y reinicia índices:

# %%
df = pd.concat(df_lista).reset_index(drop=True)
df
# Out:
#            id neo_reference_id        name designation  \
# 0     3092128          3092128  (1994 TA2)    1994 TA2
# 1     3092129          3092129  (1994 TE2)    1994 TE2
# 2     3092130          3092130   (1994 US)     1994 US
# 3     3092134          3092134  (1995 BK2)    1995 BK2
# 4     3092136          3092136  (1995 DV1)    1995 DV1
# ..        ...              ...         ...         ...
# 195  54016308         54016308  (2020 FX2)    2020 FX2
# 196  54016449         54016449   (2020 GR)     2020 GR
# 197  54016454         54016454   (2020 GU)     2020 GU
# 198  54016643         54016643  (2020 HY2)    2020 HY2
# 199  54017454         54017454  (2020 LM1)    2020 LM1
#
#                                        nasa_jpl_url  absolute_magnitude_h  \
# 0     http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092128                20.300
# 1     http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092129                22.700
# 2     http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092130                21.000
# 3     http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092134                22.600
# 4     http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3092136                23.000
# ..                                              ...                   ...
# 195  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016308                23.585
# 196  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016449                25.609
# 197  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016454                24.774
# 198  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016643                24.947
# 199  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54017454                21.529
#
#      is_potentially_hazardous_asteroid  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ..                                 ...
# 195                              False
# 196                              False
# 197                              False
# 198                              False
# 199                               True
#
#                                    close_approach_data  is_sentry_object  \
# 0    [{'close_approach_date': '1994-08-21', 'close_...             False
# 1                                                   []             False
# 2    [{'close_approach_date': '1994-09-12', 'close_...             False
# 3    [{'close_approach_date': '1995-01-29', 'close_...             False
# 4    [{'close_approach_date': '1995-01-24', 'close_...             False
# ..                                                 ...               ...
# 195  [{'close_approach_date': '2020-03-17', 'close_...             False
# 196  [{'close_approach_date': '2020-03-25', 'close_...             False
# 197  [{'close_approach_date': '2020-03-26', 'close_...             False
# 198  [{'close_approach_date': '2018-11-06', 'close_...             False
# 199  [{'close_approach_date': '2020-06-11', 'close_...             False
#
#                                             links.self  ...  \
# 0    http://www.neowsapp.com/rest/v1/neo/3092128?ap...  ...
# 1    http://www.neowsapp.com/rest/v1/neo/3092129?ap...  ...
# 2    http://www.neowsapp.com/rest/v1/neo/3092130?ap...  ...
# 3    http://www.neowsapp.com/rest/v1/neo/3092134?ap...  ...
# 4    http://www.neowsapp.com/rest/v1/neo/3092136?ap...  ...
# ..                                                 ...  ...
# 195  http://www.neowsapp.com/rest/v1/neo/54016308?a...  ...
# 196  http://www.neowsapp.com/rest/v1/neo/54016449?a...  ...
# 197  http://www.neowsapp.com/rest/v1/neo/54016454?a...  ...
# 198  http://www.neowsapp.com/rest/v1/neo/54016643?a...  ...
# 199  http://www.neowsapp.com/rest/v1/neo/54017454?a...  ...
#
#      orbital_data.aphelion_distance  orbital_data.perihelion_time  \
# 0                 4.017794307729294          2458938.860826509679
# 1                 3.238264525611692          2449639.559120815319
# 2                 4.296351145061368          2449599.393154212242
# 3                 3.778690206917434          2449738.388408613994
# 4                  4.58122325569529          2449721.531724521250
# ..                              ...                           ...
# 195               2.005554127870014          2458889.779800528263
# 196               2.292961985426653          2458912.710065096153
# 197               2.536771453265927          2458898.024146491251
# 198               4.504439265303803          2458923.200066788815
# 199               3.786446945573922          2458977.244505873983
#
#      orbital_data.mean_anomaly  orbital_data.mean_motion  \
# 0            14.23047711609944         .2308674226193818
# 1            359.3972999898663         .2926977405355879
# 2            13.30456128228865         .2177261992625065
# 3            3.393655488565221         .2588286492963218
# 4            11.72991300130177         .2133942332943736
# ..                         ...                       ...
# 195          22.53613811537284         .5401733069526612
# 196          14.14827887517385         .4595098664338557
# 197          19.67882908022213         .4327313851610539
# 198          10.16115110554943         .2799220330911933
# 199          10.92953278703327         .2715041269352981
#
#      orbital_data.equinox  orbital_data.orbit_class.orbit_class_type  \
# 0                   J2000                                        AMO
# 1                   J2000                                        AMO
# 2                   J2000                                        AMO
# 3                   J2000                                        AMO
# 4                   J2000                                        APO
# ..                    ...                                        ...
# 195                 J2000                                        APO
# 196                 J2000                                        AMO
# 197                 J2000                                        APO
# 198                 J2000                                        APO
# 199                 J2000                                        APO
#
#       orbital_data.orbit_class.orbit_class_description  \
# 0    Near-Earth asteroid orbits similar to that of ...
# 1    Near-Earth asteroid orbits similar to that of ...
# 2    Near-Earth asteroid orbits similar to that of ...
# 3    Near-Earth asteroid orbits similar to that of ...
# 4    Near-Earth asteroid orbits which cross the Ear...
# ..                                                 ...
# 195  Near-Earth asteroid orbits which cross the Ear...
# 196  Near-Earth asteroid orbits similar to that of ...
# 197  Near-Earth asteroid orbits which cross the Ear...
# 198  Near-Earth asteroid orbits which cross the Ear...
# 199  Near-Earth asteroid orbits which cross the Ear...
#
#             orbital_data.orbit_class.orbit_class_range sentry_data  \
# 0                   1.017 AU < q (perihelion) < 1.3 AU         NaN
# 1                   1.017 AU < q (perihelion) < 1.3 AU         NaN
# 2                   1.017 AU < q (perihelion) < 1.3 AU         NaN
# 3                   1.017 AU < q (perihelion) < 1.3 AU         NaN
# 4    a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# ..                                                 ...         ...
# 195  a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 196                 1.017 AU < q (perihelion) < 1.3 AU         NaN
# 197  a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 198  a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 199  a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
#
#     orbital_data.orbit_class
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 195                      NaN
# 196                      NaN
# 197                      NaN
# 198                      NaN
# 199                      NaN
#
# [200 rows x 45 columns]

# %% [markdown]
# Guarda tu dataframe en un archivo csv

# %%
df.to_csv("objetos_tierra_nasa.csv")

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reto 6: Automatizando peticiones
#
# ### 1. Objetivos:
#     - Automatizar la petición de datos a la API de la NASA por fechas.
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# ### a) Automatizando peticiones
#
# En el primer Reto realizaste una petición a la API de la NASA para pedir 5 datos de la hoja #100. Ahora, vamos a automatizar el proceso de realizar peticiones a la API para obtener una cantidad bastante mayor de datos.
#
# Vamos a obtener ahora los datos por fechas, así que tendrás que ir a la página de la [api de la NASA](https://api.nasa.gov/), para revisar cómo es posible realizar peticiones por fecha. Queremos obtener los **dos primeros meses (Enero y Febrero) del año 1995**. Observa que la API sólo permite peticiones por fecha en rangos de 7 días.
#
# Tu reto tiene los siguientes pasos:
#
# 1. Revisa la documentación de la API de la NASA para entender cómo realizar peticiones por fecha.
# 2. Realiza una primera petición de prueba para entender el formato de los datos que obtienes de regreso (cómo extraemos los datos que necesitamos y qué estructura tienen).
# 2. Escribe el código necesario para automatizar las peticiones a la API y obtener los meses de Enero y Febrero del año 1995.
# 3. Almacena los datos de cada petición y luego usa esos datos para crear `DataFrames`.
# 4. Concatena verticalmente tus `DataFrames` para obtener un `DataFrame` final que contenga todos los datos de tus peticiones. Cada fila tiene que corresponder a un objeto espacial.
# 5. Guarda tu `DataFrame` con el nombre de `near_earth_objects-january_february_1995-raw.csv`.
#
# > **Nota**: En este momento no te preocupes por explorar o limpiar tu dataset. Eso lo haremos en la siguiente sesión. Lo que sí tienes que asegurarte es de normalizar tus datos antes de convertirlos en `DataFrame`.
#
# ¡Mucha suerte!
